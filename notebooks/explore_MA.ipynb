# %%
# %cd /media/Storage_2/Sam
import compute as c
import pandas as pd
all='ALL'
# Out:
# /media/Storage_2/Sam

# %%
# %cd data/MA
MA_dict=c.make_df_dict('MA', [25,50,75,1,2,4,6,8], 4)
# Out:
# /media/Storage_2/Sam/data/MA
# MA_E25_R1
# MA_E25_R2
# MA_E25_R3
# MA_E25_R4
# MA_E50_R1
# MA_E50_R2
# MA_E50_R3
# MA_E50_R4
# MA_E75_R1
# MA_E75_R2
# MA_E75_R3
# MA_E75_R4
# MA_E1_R1
# MA_E1_R2
# MA_E1_R3
# MA_E1_R4
# MA_E2_R1
# MA_E2_R2
# MA_E2_R3
# MA_E2_R4
# MA_E4_R1
# MA_E4_R2
# MA_E4_R3
# MA_E4_R4
# MA_E6_R1
# MA_E6_R2
# MA_E6_R3
# MA_E6_R4
# MA_E8_R1
# MA_E8_R2
# MA_E8_R3
# MA_E8_R4

# %%
MA_dict=c.add_real_to_dict(MA_dict,'the_real_MA')

# %%
atts=[all, all, all, all, all, all, [1]]
title='MA 1940: White Population'
sd= c.make_stat_dict(MA_dict,atts)
c.plot_stat_dict(sd ,title)
print(sd)
# Out:
# {'0.25': [4269252, 4269189, 4269280, 4269172], '0.5': [4269181, 4269134, 4269132, 4269242], '0.75': [4269186, 4269214, 4269253, 4269161], '1.0': [4269191, 4269268, 4269206, 4269240], '2.0': [4269189, 4269187, 4269200, 4269228], '4.0': [4269195, 4269206, 4269201, 4269190], '6.0': [4269192, 4269208, 4269205, 4269196], '8.0': [4269203, 4269201, 4269199, 4269198]}
# {(25, 1): 4269252, (25, 2): 4269189, (25, 3): 4269280, (25, 4): 4269172, (50, 1): 4269181, (50, 2): 4269134, (50, 3): 4269132, (50, 4): 4269242, (75, 1): 4269186, (75, 2): 4269214, (75, 3): 4269253, (75, 4): 4269161, (1, 1): 4269191, (1, 2): 4269268, (1, 3): 4269206, (1, 4): 4269240, (2, 1): 4269189, (2, 2): 4269187, (2, 3): 4269200, (2, 4): 4269228, (4, 1): 4269195, (4, 2): 4269206, (4, 3): 4269201, (4, 4): 4269190, (6, 1): 4269192, (6, 2): 4269208, (6, 3): 4269205, (6, 4): 4269196, (8, 1): 4269203, (8, 2): 4269201, (8, 3): 4269199, (8, 4): 4269198, 'real': 4269199}

# %%
atts=[all, all, all, all, all, all, [4]]
title='MA 1940: Chinese Population'
sd= c.make_stat_dict(MA_dict,atts)
c.plot_stat_dict(sd ,title)
# Out:
# {'0.25': [3086, 3141, 3250, 2971], '0.5': [3136, 3131, 3176, 3061], '0.75': [3099, 3165, 3079, 3070], '1.0': [3070, 3047, 3065, 3124], '2.0': [3118, 3103, 3098, 3085], '4.0': [3090, 3109, 3101, 3110], '6.0': [3109, 3100, 3099, 3101], '8.0': [3100, 3095, 3099, 3110]}
# True

# %%
atts=[all, all, all, all, all, all, [4,5,6]]
title='MA 1940: Asian Population'
sd= c.make_stat_dict(MA_dict,atts)
c.plot_stat_dict(sd ,title)
# Out:
# {'0.25': [3633, 3671, 3765, 3546], '0.5': [3472, 3576, 3600, 3502], '0.75': [3532, 3706, 3451, 3521], '1.0': [3548, 3452, 3510, 3590], '2.0': [3539, 3569, 3542, 3513], '4.0': [3543, 3553, 3552, 3554], '6.0': [3551, 3536, 3541, 3533], '8.0': [3540, 3542, 3543, 3551]}
# True

# %%
atts=[all, all, all, all, all, all, [5]]
title='MA 1940: Japanese Population'
sd= c.make_stat_dict(MA_dict,atts)
c.plot_stat_dict(sd ,title)
# Out:
# {'0.25': [152, 168, 11, 194], '0.5': [119, 89, 84, 130], '0.75': [108, 154, 80, 125], '1.0': [118, 100, 122, 122], '2.0': [108, 126, 111, 101], '4.0': [128, 114, 121, 118], '6.0': [116, 111, 108, 105], '8.0': [111, 116, 112, 113]}
# True

# %%
atts=[all, all, all, all, all, all, [3]]
title='MA 1940: Native Population'
sd= c.make_stat_dict(MA_dict,atts)
c.plot_stat_dict(sd ,title)
# Out:
# {'0.25': [868, 799, 642, 800], '0.5': [948, 860, 843, 832], '0.75': [893, 820, 836, 848], '1.0': [879, 829, 857, 868], '2.0': [848, 844, 842, 854], '4.0': [852, 843, 841, 848], '6.0': [852, 851, 851, 848], '8.0': [846, 846, 845, 845]}
# True

# %%
atts=[all, all, all, all, all, all, [2]]
title='MA 1940: Black Population'
sd= c.make_stat_dict(MA_dict,atts)
c.plot_stat_dict(sd ,title)
# Out:
# {'0.25': [1077534, 1077446, 1077654, 1077668], '0.5': [1077605, 1077597, 1077640, 1077607], '0.75': [1077651, 1077539, 1077618, 1077609], '1.0': [1077637, 1077649, 1077699, 1077646], '2.0': [1077654, 1077635, 1077657, 1077656], '4.0': [1077653, 1077630, 1077642, 1077641], '6.0': [1077640, 1077651, 1077641, 1077645], '8.0': [1077642, 1077641, 1077644, 1077645]}
# True

# %%
atts=[all, all, all, all, all, [2], [2]]
title='MA 1940: Black Hispanic Population'
sd= c.make_stat_dict(MA_dict,atts)
c.plot_stat_dict(sd ,title)
# Out:
# {'0.25': [734, 856, 710, 856], '0.5': [782, 880, 851, 827], '0.75': [793, 737, 828, 869], '1.0': [809, 837, 831, 775], '2.0': [818, 809, 816, 810], '4.0': [817, 810, 806, 813], '6.0': [813, 813, 812, 817], '8.0': [812, 816, 818, 814]}
# True

# %%
atts=[all, all, all, all, all, [2], [1]]
title='MA 1940: White Hispanic Population'
sd= c.make_stat_dict(MA_dict,atts)
c.plot_stat_dict(sd ,title)
# Out:
# {'0.25': [16220, 16102, 16129, 16177], '0.5': [16151, 16139, 16086, 16173], '0.75': [16162, 16164, 16207, 16148], '1.0': [16129, 16191, 16124, 16181], '2.0': [16136, 16126, 16144, 16148], '4.0': [16132, 16146, 16139, 16135], '6.0': [16143, 16147, 16140, 16138], '8.0': [16145, 16136, 16137, 16139]}
# True

# %%
atts=[all, all, all, all, all, [2], [4,5,6]]
title='MA 1940: Asian Hispanic Population'
sd= c.make_stat_dict(MA_dict,atts)
c.plot_stat_dict(sd ,title)
# Out:
# {'0.25': [28, 121, 11, 21], '0.5': [8, 32, 2, 19], '0.75': [19, 19, 17, 15], '1.0': [3, 1, 22, 25], '2.0': [30, 16, 16, 12], '4.0': [16, 14, 14, 16], '6.0': [20, 12, 12, 17], '8.0': [11, 13, 10, 22]}
# True

# %%
atts=[all, all, all, all, all, [2], [3]]
title='MA 1940: Native Hispanic Population'
sd= c.make_stat_dict(MA_dict,atts)
c.plot_stat_dict(sd ,title)
# Out:
# {'0.25': [14, 26, 1, 14], '0.5': [35, 2, 0, 19], '0.75': [17, 16, 13, 19], '1.0': [40, 17, 12, 25], '2.0': [20, 32, 28, 19], '4.0': [24, 19, 17, 14], '6.0': [25, 20, 19, 20], '8.0': [19, 21, 17, 19]}
# True

# %%
atts=[all, all, all, [3], all, all, all]
title='MA 1940: GQ p'
sd= c.make_stat_dict(MA_dict,atts)
c.plot_stat_dict(sd ,title)

# %%
county_race=c.make_entire_race_county_dict(MA_dict)

# %%
c.plot_race_frac_by_county(county_race, 'white', 'MA')
c.plot_diff_in_race_frac_by_county(county_race, 'white', 'MA')

# %%
c.plot_race_frac_by_county(county_race, 'black', 'MA')
c.plot_diff_in_race_frac_by_county(county_race, 'black', 'MA')

# %%
c.plot_race_frac_by_county(county_race, 'other', 'MA')
c.plot_diff_in_race_frac_by_county(county_race, 'other', 'MA')
