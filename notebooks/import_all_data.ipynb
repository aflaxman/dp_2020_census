# %%
import numpy as np, matplotlib.pyplot as plt, pandas as pd
pd.set_option('display.max_rows', 10)
# !date

# %load_ext autoreload
# %autoreload 2
# %cd data
# Out:
# Wed Jun 12 19:03:31 EDT 2019
# /media/Storage_2/Sam/data

# %%
# !wget https://www2.census.gov/census_1940/EXT1940USCB-EPSILON0.25-RUN2.zip
# Out:
# --2019-06-12 15:57:39--  https://www2.census.gov/census_1940/EXT1940USCB-EPSILON0.25-RUN2.zip
# Resolving www2.census.gov (www2.census.gov)... 2001:559:19:f8a3::208c, 2001:559:19:f898::208c, 184.29.222.82
# Connecting to www2.census.gov (www2.census.gov)|2001:559:19:f8a3::208c|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 959926018 (915M) [application/zip]
# Saving to: ‘EXT1940USCB-EPSILON0.25-RUN2.zip’
#
# EXT1940USCB-EPSILON 100%[===================>] 915.46M   836KB/s    in 18m 43s
#
# 2019-06-12 16:16:22 (835 KB/s) - ‘EXT1940USCB-EPSILON0.25-RUN2.zip’ saved [959926018/959926018]

# %%
# !wget https://www2.census.gov/census_1940/EXT1940USCB-EPSILON0.25-RUN3.zip
# Out:
# --2019-06-12 16:22:18--  https://www2.census.gov/census_1940/EXT1940USCB-EPSILON0.25-RUN3.zip
# Resolving www2.census.gov (www2.census.gov)... 2001:559:19:f898::208c, 2001:559:19:f8a3::208c, 184.29.222.82
# Connecting to www2.census.gov (www2.census.gov)|2001:559:19:f898::208c|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 959408850 (915M) [application/zip]
# Saving to: ‘EXT1940USCB-EPSILON0.25-RUN3.zip’
#
# EXT1940USCB-EPSILON 100%[===================>] 914.96M   833KB/s    in 18m 55s
#
# 2019-06-12 16:41:14 (825 KB/s) - ‘EXT1940USCB-EPSILON0.25-RUN3.zip’ saved [959408850/959408850]

# %%
# !wget https://www2.census.gov/census_1940/EXT1940USCB-EPSILON0.25-RUN4.zip
# Out:
# --2019-06-12 16:46:32--  https://www2.census.gov/census_1940/EXT1940USCB-EPSILON0.25-RUN4.zip
# Resolving www2.census.gov (www2.census.gov)... 2001:559:19:f898::208c, 2001:559:19:f8a3::208c, 184.29.222.82
# Connecting to www2.census.gov (www2.census.gov)|2001:559:19:f898::208c|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 959074553 (915M) [application/zip]
# Saving to: ‘EXT1940USCB-EPSILON0.25-RUN4.zip’
#
# EXT1940USCB-EPSILON 100%[===================>] 914.64M   826KB/s    in 18m 59s
#
# 2019-06-12 17:05:31 (823 KB/s) - ‘EXT1940USCB-EPSILON0.25-RUN4.zip’ saved [959074553/959074553]

# %%
# !wget https://www2.census.gov/census_1940/EXT1940USCB-EPSILON0.50-RUN1.zip
# !wget https://www2.census.gov/census_1940/EXT1940USCB-EPSILON0.50-RUN2.zip
# !wget https://www2.census.gov/census_1940/EXT1940USCB-EPSILON0.50-RUN3.zip
# !wget https://www2.census.gov/census_1940/EXT1940USCB-EPSILON0.50-RUN4.zip
# Out:
# --2019-06-12 17:07:13--  https://www2.census.gov/census_1940/EXT1940USCB-EPSILON0.50-RUN1.zip
# Resolving www2.census.gov (www2.census.gov)... 2001:559:19:f8a3::208c, 2001:559:19:f898::208c, 104.92.13.103
# Connecting to www2.census.gov (www2.census.gov)|2001:559:19:f8a3::208c|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 955103802 (911M) [application/zip]
# Saving to: ‘EXT1940USCB-EPSILON0.50-RUN1.zip’
#
# EXT1940USCB-EPSILON 100%[===================>] 910.86M  3.50MB/s    in 4m 21s
#
# 2019-06-12 17:11:34 (3.49 MB/s) - ‘EXT1940USCB-EPSILON0.50-RUN1.zip’ saved [955103802/955103802]
#
# --2019-06-12 17:11:34--  https://www2.census.gov/census_1940/EXT1940USCB-EPSILON0.50-RUN2.zip
# Resolving www2.census.gov (www2.census.gov)... 2001:559:19:f898::208c, 2001:559:19:f8a3::208c, 104.92.13.103
# Connecting to www2.census.gov (www2.census.gov)|2001:559:19:f898::208c|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
# !wget https://www2.census.gov/census_1940/EXT1940USCB-EPSILON0.50-RUN3.zip
# Out:
# --2019-06-12 17:53:26--  https://www2.census.gov/census_1940/EXT1940USCB-EPSILON0.50-RUN3.zip
# Resolving www2.census.gov (www2.census.gov)... 2001:559:19:f898::208c, 2001:559:19:f8a3::208c, 104.92.13.103
# Connecting to www2.census.gov (www2.census.gov)|2001:559:19:f898::208c|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 954009391 (910M) [application/zip]
# Saving to: ‘EXT1940USCB-EPSILON0.50-RUN3.zip’
#
# EXT1940USCB-EPSILON 100%[===================>] 909.81M  3.50MB/s    in 4m 21s
#
# 2019-06-12 17:57:47 (3.49 MB/s) - ‘EXT1940USCB-EPSILON0.50-RUN3.zip’ saved [954009391/954009391]

# %%
# !wget -c https://www2.census.gov/census_1940/EXT1940USCB-EPSILON0.75-RUN1.zip
# !wget https://www2.census.gov/census_1940/EXT1940USCB-EPSILON0.75-RUN2.zip
# !wget https://www2.census.gov/census_1940/EXT1940USCB-EPSILON0.75-RUN3.zip
# !wget https://www2.census.gov/census_1940/EXT1940USCB-EPSILON0.75-RUN4.zip
# !wget https://www2.census.gov/census_1940/EXT1940USCB-EPSILON1.0-RUN1.zip
# !wget https://www2.census.gov/census_1940/EXT1940USCB-EPSILON1.0-RUN2.zip
# !wget https://www2.census.gov/census_1940/EXT1940USCB-EPSILON1.0-RUN3.zip
# !wget https://www2.census.gov/census_1940/EXT1940USCB-EPSILON1.0-RUN4.zip
# !wget https://www2.census.gov/census_1940/EXT1940USCB-EPSILON2.0-RUN1.zip
# !wget https://www2.census.gov/census_1940/EXT1940USCB-EPSILON2.0-RUN2.zip
# !wget https://www2.census.gov/census_1940/EXT1940USCB-EPSILON2.0-RUN3.zip
# !wget https://www2.census.gov/census_1940/EXT1940USCB-EPSILON2.0-RUN4.zip
# !wget https://www2.census.gov/census_1940/EXT1940USCB-EPSILON4.0-RUN1.zip
# !wget https://www2.census.gov/census_1940/EXT1940USCB-EPSILON4.0-RUN2.zip
# !wget https://www2.census.gov/census_1940/EXT1940USCB-EPSILON4.0-RUN3.zip
# !wget https://www2.census.gov/census_1940/EXT1940USCB-EPSILON4.0-RUN4.zip
# !wget https://www2.census.gov/census_1940/EXT1940USCB-EPSILON6.0-RUN1.zip
# !wget https://www2.census.gov/census_1940/EXT1940USCB-EPSILON6.0-RUN2.zip
# !wget https://www2.census.gov/census_1940/EXT1940USCB-EPSILON6.0-RUN3.zip
# !wget https://www2.census.gov/census_1940/EXT1940USCB-EPSILON6.0-RUN4.zip
# !wget https://www2.census.gov/census_1940/EXT1940USCB-EPSILON8.0-RUN1.zip
# !wget https://www2.census.gov/census_1940/EXT1940USCB-EPSILON8.0-RUN2.zip
# !wget https://www2.census.gov/census_1940/EXT1940USCB-EPSILON8.0-RUN3.zip
# !wget https://www2.census.gov/census_1940/EXT1940USCB-EPSILON8.0-RUN4.zip
# Out:
# --2019-06-12 19:03:39--  https://www2.census.gov/census_1940/EXT1940USCB-EPSILON0.75-RUN1.zip
# Resolving www2.census.gov (www2.census.gov)... 2001:559:19:f8a3::208c, 2001:559:19:f898::208c, 104.92.13.103
# Connecting to www2.census.gov (www2.census.gov)|2001:559:19:f8a3::208c|:443... connected.
# HTTP request sent, awaiting response... 200 OK
#
#     The file is already fully retrieved; nothing to do.
#
# --2019-06-12 19:03:39--  https://www2.census.gov/census_1940/EXT1940USCB-EPSILON0.75-RUN2.zip
# Resolving www2.census.gov (www2.census.gov)... 2001:559:19:f8a3::208c, 2001:559:19:f898::208c, 104.92.13.103
# Connecting to www2.census.gov (www2.census.gov)|2001:559:19:f8a3::208c|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 955671180 (911M) [application/zip]
# Saving to: ‘EXT1940USCB-EPSILON0.75-RUN2.zip.1’
#
# EXT1940USCB-EPSILON 100%[===================>] 911.40M  3.50MB/s    in 4m 21s
#
# ...

# %%
ls
# Out:
# EXT1940USCB-EPSILON0.25-RUN1.zip*  EXT1940USCB-EPSILON0.50-RUN3.zip*
# EXT1940USCB-EPSILON0.25-RUN2.zip*  EXT1940USCB-EPSILON0.50-RUN4.zip*
# EXT1940USCB-EPSILON0.25-RUN3.zip*  GA_Ep25_R1.csv*
# EXT1940USCB-EPSILON0.25-RUN4.zip*  MDF_PER.txt*
# EXT1940USCB-EPSILON0.50-RUN1.zip*  MDF_UNIT.txt*
# EXT1940USCB-EPSILON0.50-RUN2.zip*  test/

# %%
# !wget -c  https://www2.census.gov/census_1940/EXT1940USCB-EPSILON2.0-RUN3.zip
# Out:
# --2019-06-13 21:18:54--  https://www2.census.gov/census_1940/EXT1940USCB-EPSILON2.0-RUN2.zip
# Resolving www2.census.gov (www2.census.gov)... 2001:559:19:f898::208c, 2001:559:19:f8a3::208c, 184.29.222.82
# Connecting to www2.census.gov (www2.census.gov)|2001:559:19:f898::208c|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘EXT1940USCB-EPSILON2.0-RUN2.zip’
#
# EXT1940USCB-EPSILON     [   <=>              ] 908.02M  3.49MB/s    in 4m 21s
#
# 2019-06-13 21:23:16 (3.48 MB/s) - ‘EXT1940USCB-EPSILON2.0-RUN2.zip’ saved [952123991]
#
# --2019-06-13 21:23:16--  https://www2.census.gov/census_1940/EXT1940USCB-EPSILON2.0-RUN3.zip
# Resolving www2.census.gov (www2.census.gov)... 2001:559:19:f898::208c, 2001:559:19:f8a3::208c, 184.29.222.82
# Connecting to www2.census.gov (www2.census.gov)|2001:559:19:f898::208c|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# ...

# %%
# !wget -c  https://www2.census.gov/census_1940/EXT1940USCB-EPSILON2.0-RUN3.zip
# Out:
# --2019-06-13 21:52:40--  https://www2.census.gov/census_1940/EXT1940USCB-EPSILON2.0-RUN3.zip
# Resolving www2.census.gov (www2.census.gov)... 2001:559:19:f8a3::208c, 2001:559:19:f898::208c, 184.29.222.82
# Connecting to www2.census.gov (www2.census.gov)|2001:559:19:f8a3::208c|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘EXT1940USCB-EPSILON2.0-RUN3.zip’
#
# EXT1940USCB-EPSILON     [      <=>           ] 909.32M   343KB/s    in 41m 30s
#
# 2019-06-13 22:34:11 (374 KB/s) - ‘EXT1940USCB-EPSILON2.0-RUN3.zip’ saved [953490972]
