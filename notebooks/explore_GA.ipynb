# %%
# %cd /media/Storage_2/Sam
import compute as c
import pandas as pd
all='ALL'
# Out:
# /media/Storage_2/Sam

# %%
# %cd data/GA
GA_dict=c.make_df_dict('GA', [25,50,75,1,2,4,6,8], 4)
# Out:
# /media/Storage_2/Sam/data/GA
# GA_E25_R1
# GA_E25_R2
# GA_E25_R3
# GA_E25_R4
# GA_E50_R1
# GA_E50_R2
# GA_E50_R3
# GA_E50_R4
# GA_E75_R1
# GA_E75_R2
# GA_E75_R3
# GA_E75_R4
# GA_E1_R1
# GA_E1_R2
# GA_E1_R3
# GA_E1_R4
# GA_E2_R1
# GA_E2_R2
# GA_E2_R3
# GA_E2_R4
# GA_E4_R1
# GA_E4_R2
# GA_E4_R3
# GA_E4_R4
# GA_E6_R1
# GA_E6_R2
# GA_E6_R3
# GA_E6_R4
# GA_E8_R1
# GA_E8_R2
# GA_E8_R3
# GA_E8_R4

# %%
GA_dict=c.add_real_to_dict(GA_dict,'the_real_GA')

# %%
atts=[all, all, all, all, all, all, [1]]
title='GA 1940: White Population'
sd= c.make_stat_dict(GA_dict,atts)
c.plot_stat_dict(sd ,title)
print(sd)
# Out:
# {'0.25': [2049874, 2049969, 2049785, 2049744], '0.5': [2049984, 2049918, 2049784, 2049759], '0.75': [2049800, 2049904, 2049806, 2049921], '1.0': [2049840, 2049874, 2049817, 2049843], '2.0': [2049831, 2049860, 2049812, 2049839], '4.0': [2049844, 2049843, 2049838, 2049842], '6.0': [2049842, 2049834, 2049833, 2049844], '8.0': [2049840, 2049843, 2049835, 2049841]}
# {(25, 1): 2049874, (25, 2): 2049969, (25, 3): 2049785, (25, 4): 2049744, (50, 1): 2049984, (50, 2): 2049918, (50, 3): 2049784, (50, 4): 2049759, (75, 1): 2049800, (75, 2): 2049904, (75, 3): 2049806, (75, 4): 2049921, (1, 1): 2049840, (1, 2): 2049874, (1, 3): 2049817, (1, 4): 2049843, (2, 1): 2049831, (2, 2): 2049860, (2, 3): 2049812, (2, 4): 2049839, (4, 1): 2049844, (4, 2): 2049843, (4, 3): 2049838, (4, 4): 2049842, (6, 1): 2049842, (6, 2): 2049834, (6, 3): 2049833, (6, 4): 2049844, (8, 1): 2049840, (8, 2): 2049843, (8, 3): 2049835, (8, 4): 2049841, 'real': 2049840}

# %%
atts=[all, all, all, all, all, all, [4]]
title='GA 1940: Chinese Population'
sd= c.make_stat_dict(GA_dict,atts)
c.plot_stat_dict(sd ,title)
# Out:
# {'0.25': [404, 469, 384, 332], '0.5': [365, 428, 444, 436], '0.75': [423, 400, 418, 378], '1.0': [409, 435, 388, 392], '2.0': [410, 412, 422, 415], '4.0': [409, 414, 431, 425], '6.0': [421, 422, 423, 420], '8.0': [419, 419, 423, 421]}
# True

# %%
atts=[all, all, all, all, all, all, [4,5,6]]
title='GA 1940: Asian Population'
sd= c.make_stat_dict(GA_dict,atts)
c.plot_stat_dict(sd ,title)
# Out:
# {'0.25': [461, 537, 553, 512], '0.5': [429, 494, 540, 605], '0.75': [536, 546, 525, 436], '1.0': [470, 495, 475, 457], '2.0': [485, 471, 499, 479], '4.0': [478, 496, 496, 499], '6.0': [494, 495, 500, 485], '8.0': [491, 493, 494, 490]}
# True

# %%
atts=[all, all, all, all, all, all, [5]]
title='GA 1940: Japanese Population'
sd= c.make_stat_dict(GA_dict,atts)
c.plot_stat_dict(sd ,title)
# Out:
# {'0.25': [35, 45, 74, 117], '0.5': [4, 34, 58, 11], '0.75': [65, 36, 16, 7], '1.0': [26, 24, 19, 12], '2.0': [31, 15, 29, 23], '4.0': [13, 34, 13, 17], '6.0': [17, 22, 16, 13], '8.0': [19, 18, 23, 17]}
# True

# %%
atts=[all, all, all, all, all, all, [3]]
title='GA 1940: Native Population'
sd= c.make_stat_dict(GA_dict,atts)
c.plot_stat_dict(sd ,title)
# Out:
# {'0.25': [263, 180, 140, 208], '0.5': [114, 123, 168, 161], '0.75': [145, 143, 183, 166], '1.0': [185, 114, 141, 186], '2.0': [162, 166, 164, 158], '4.0': [157, 163, 156, 150], '6.0': [156, 152, 158, 158], '8.0': [159, 155, 159, 156]}
# True

# %%
atts=[all, all, all, all, all, all, [2]]
title='GA 1940: Black Population'
sd= c.make_stat_dict(GA_dict,atts)
c.plot_stat_dict(sd ,title)
# Out:
# {'0.25': [1077534, 1077446, 1077654, 1077668], '0.5': [1077605, 1077597, 1077640, 1077607], '0.75': [1077651, 1077539, 1077618, 1077609], '1.0': [1077637, 1077649, 1077699, 1077646], '2.0': [1077654, 1077635, 1077657, 1077656], '4.0': [1077653, 1077630, 1077642, 1077641], '6.0': [1077640, 1077651, 1077641, 1077645], '8.0': [1077642, 1077641, 1077644, 1077645]}
# True

# %%
atts=[all, all, all, all, all, [2], [2]]
title='GA 1940: Black Hispanic Population'
sd= c.make_stat_dict(GA_dict,atts)
c.plot_stat_dict(sd ,title)
# Out:
# {'0.25': [1874, 1822, 1903, 1931], '0.5': [1922, 1850, 1969, 1908], '0.75': [1973, 1969, 1910, 1961], '1.0': [1957, 1970, 1966, 1963], '2.0': [1956, 1971, 1970, 1948], '4.0': [1960, 1943, 1964, 1955], '6.0': [1950, 1955, 1954, 1955], '8.0': [1954, 1949, 1954, 1954]}
# True

# %%
atts=[all, all, all, all, all, [2], [1]]
title='GA 1940: White Hispanic Population'
sd= c.make_stat_dict(GA_dict,atts)
c.plot_stat_dict(sd ,title)
# Out:
# {'0.25': [5069, 5205, 4960, 5121], '0.5': [5252, 5124, 5069, 5058], '0.75': [5040, 5077, 5042, 5089], '1.0': [5072, 5086, 5064, 5063], '2.0': [5076, 5082, 5059, 5082], '4.0': [5075, 5077, 5067, 5075], '6.0': [5075, 5075, 5071, 5070], '8.0': [5074, 5073, 5073, 5073]}
# True

# %%
atts=[all, all, all, all, all, [2], [4,5,6]]
title='GA 1940: Asian Hispanic Population'
sd= c.make_stat_dict(GA_dict,atts)
c.plot_stat_dict(sd ,title)
# Out:
# {'0.25': [27, 18, 39, 22], '0.5': [3, 5, 29, 11], '0.75': [6, 25, 12, 19], '1.0': [18, 4, 16, 5], '2.0': [13, 12, 27, 10], '4.0': [2, 6, 10, 9], '6.0': [5, 3, 6, 3], '8.0': [5, 4, 10, 4]}
# True

# %%
atts=[all, all, all, all, all, [2], [3]]
title='GA 1940: Native Hispanic Population'
sd= c.make_stat_dict(GA_dict,atts)
c.plot_stat_dict(sd ,title)
# Out:
# {'0.25': [6, 12, 3, 85], '0.5': [0, 8, 45, 0], '0.75': [0, 9, 36, 15], '1.0': [6, 5, 20, 20], '2.0': [7, 5, 9, 7], '4.0': [4, 0, 0, 0], '6.0': [3, 1, 3, 2], '8.0': [2, 0, 0, 0]}
# True

# %%
county_race=c.make_entire_race_county_dict(GA_dict)

# %%
c.plot_race_frac_by_county(county_race, 'white', 'GA')
c.plot_diff_in_race_frac_by_county(county_race, 'white', 'GA')

# %%
c.plot_race_frac_by_county(county_race, 'black', 'GA')
c.plot_diff_in_race_frac_by_county(county_race, 'black', 'GA')

# %%
c.plot_race_frac_by_county(county_race, 'other', 'GA')
c.plot_diff_in_race_frac_by_county(county_race, 'other', 'GA')
